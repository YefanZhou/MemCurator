# %%
import numpy as np

# %%
nonthink_reason_w_bug = np.array([0.357, 0.329, 0.357]  ) * 100
thinking_origin_w_bug = np.array([0.45, 0.5,  0.4643]) * 100  
thinking_origin_remove_w_bug = np.array([0.4929, 0.4643, 0.4714]) * 100    
thinking_origin_reason_w_bug  =   np.array([0.4, 0.4429, 0.4289]) * 100

nonthink_origin_wo_bug = np.array([0.264]) * 100   
nonthink_origin_remove_wo_bug = np.array([0.379]) * 100    
nonthink_origin_reason_wo_bug  =   []

thinking_origin_wo_bug = [50.00, 52.86, 46.43]   
thinking_origin_remove_wo_bug = [47.14, 50.00, 47.86]    
thinking_origin_reason_wo_bug  =   []

thinking_origin_wo_bug_32b = [55.71, 60.00, 57.14]   
thinking_origin_remove_wo_bug_32b = [59.29, 57.14]

# %%
lists = {
    "nonthink_reason_w_bug": nonthink_reason_w_bug,
    "thinking_origin_w_bug": thinking_origin_w_bug,
    "thinking_origin_remove_w_bug": thinking_origin_remove_w_bug,
    "thinking_origin_reason_w_bug": thinking_origin_reason_w_bug,
    "nonthink_origin_wo_bug": nonthink_origin_wo_bug,
    "nonthink_origin_remove_wo_bug": nonthink_origin_remove_wo_bug,
    "nonthink_origin_reason_wo_bug": nonthink_origin_reason_wo_bug,
    "thinking_origin_wo_bug": thinking_origin_wo_bug,
    "thinking_origin_remove_wo_bug": thinking_origin_remove_wo_bug,
    "thinking_origin_reason_wo_bug": thinking_origin_reason_wo_bug,
    "thinking_origin_wo_bug_32b": thinking_origin_wo_bug_32b,
    "thinking_origin_remove_wo_bug_32b": thinking_origin_remove_wo_bug_32b,
}

for name, lst in lists.items():
    if len(lst) > 0:
        print(f"{name}: {np.mean(lst):.2f} ± {np.std(lst):.2f} N = {len(lst)}")
    else:
        print(f"{name}: (empty)")
# Out:
# nonthink_reason_w_bug: 34.77 ± 1.32 N = 3
# thinking_origin_w_bug: 47.14 ± 2.10 N = 3
# thinking_origin_remove_w_bug: 47.62 ± 1.22 N = 3
# thinking_origin_reason_w_bug: 42.39 ± 1.79 N = 3
# nonthink_origin_wo_bug: 26.40 ± 0.00 N = 1
# nonthink_origin_remove_wo_bug: 37.90 ± 0.00 N = 1
# nonthink_origin_reason_wo_bug: (empty)
# thinking_origin_wo_bug: 49.76 ± 2.63 N = 3
# thinking_origin_remove_wo_bug: 48.33 ± 1.21 N = 3
# thinking_origin_reason_wo_bug: (empty)
# thinking_origin_wo_bug_32b: 54.05 ± 5.66 N = 3
# thinking_origin_remove_wo_bug_32b: 58.22 ± 1.07 N = 2
